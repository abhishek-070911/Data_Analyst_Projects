# %%
# Importing libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Importing dataset

import_df = pd.read_csv(r'D:\Prot\Data Analyst\UM selected projects\I_Electric Vehicles\Electric Vehicle Sales by State in India_Edited.csv')

# %%
# Creating copy of the original dataframe

ev_df = import_df.copy()

# %%
# Querying for 1st 5 rows

ev_df[:5]
# Out:
#    Year Month_Name        Date           State         Vehicle_Class  \
# 0  2014    January  2014-01-01  Andhra Pradesh       ADAPTED VEHICLE
# 1  2014    January  2014-01-01  Andhra Pradesh  AGRICULTURAL TRACTOR
# 2  2014    January  2014-01-01  Andhra Pradesh             AMBULANCE
# 3  2014    January  2014-01-01  Andhra Pradesh   ARTICULATED VEHICLE
# 4  2014    January  2014-01-01  Andhra Pradesh                   BUS
#
#   Vehicle_Category Vehicle_Type  EV_Sales_Quantity
# 0           Others       Others                  0
# 1           Others       Others                  0
# 2           Others       Others                  0
# 3           Others       Others                  0
# 4              Bus          Bus                  0

# %%
# Querying for missing values

ev_df.isnull().sum()
# Out:
# Year                 0
# Month_Name           0
# Date                 0
# State                0
# Vehicle_Class        0
# Vehicle_Category     0
# Vehicle_Type         0
# EV_Sales_Quantity    0
# dtype: int64

# %%
# Summary of the dataset

ev_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96845 entries, 0 to 96844
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               96845 non-null  int64
#  1   Month_Name         96845 non-null  object
#  2   Date               96845 non-null  object
#  3   State              96845 non-null  object
#  4   Vehicle_Class      96845 non-null  object
#  5   Vehicle_Category   96845 non-null  object
#  6   Vehicle_Type       96845 non-null  object
#  7   EV_Sales_Quantity  96845 non-null  int64
# dtypes: int64(2), object(6)
# memory usage: 5.9+ MB

# %%
# Changing data type of date from object to datetime

ev_df['Date'] = pd.to_datetime(ev_df['Date'])

# %%
# Analysing total number of rows and columns

ev_df.shape
# Out:
# (96845, 8)

# %%
# Checking for duplicate values

ev_df[ev_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Year, Month_Name, Date, State, Vehicle_Class, Vehicle_Category, Vehicle_Type, EV_Sales_Quantity]
# Index: []

# %% [markdown]
# * There are no duplicates.

# %%
# Statistical summary

ev_df.describe(include = "all").T
# Out:
#                      count unique          top   freq  \
# Year               96845.0    NaN          NaN    NaN
# Month_Name           96845     12      January   8853
# Date                 96845    NaN          NaN    NaN
# State                96845     34  Maharashtra   4912
# Vehicle_Class        96845     73    MOTOR CAR   4111
# Vehicle_Category     96845      5       Others  54423
# Vehicle_Type         96845     12       Others  54423
# EV_Sales_Quantity  96845.0    NaN          NaN    NaN
#
#                                             mean                  min  \
# Year                                 2018.622768               2014.0
# Month_Name                                   NaN                  NaN
# Date               2018-08-21 18:58:21.900975872  2014-01-01 00:00:00
# State                                        NaN                  NaN
# Vehicle_Class                                NaN                  NaN
# Vehicle_Category                             NaN                  NaN
# Vehicle_Type                                 NaN                  NaN
# EV_Sales_Quantity                      37.108896                  0.0
#
#                                    25%                  50%  \
# Year                            2016.0               2019.0
# Month_Name                         NaN                  NaN
# Date               2016-01-08 00:00:00  2019-01-02 00:00:00
# State                              NaN                  NaN
# Vehicle_Class                      NaN                  NaN
# Vehicle_Category                   NaN                  NaN
# Vehicle_Type                       NaN                  NaN
# EV_Sales_Quantity                  0.0                  0.0
#
#                                    75%                  max         std
# Year                            2021.0               2024.0    2.895581
# Month_Name                         NaN                  NaN         NaN
# Date               2021-01-09 00:00:00  2024-01-01 00:00:00         NaN
# State                              NaN                  NaN         NaN
# Vehicle_Class                      NaN                  NaN         NaN
# Vehicle_Category                   NaN                  NaN         NaN
# Vehicle_Type                       NaN                  NaN         NaN
# EV_Sales_Quantity                  0.0              20584.0  431.566675

# %%
# Calculating total sales per year

total_sales_years = ev_df.groupby('Year')[['EV_Sales_Quantity']].sum().reset_index()
total_sales_years
# Out:
#     Year  EV_Sales_Quantity
# 0   2014               2392
# 1   2015               7805
# 2   2016              49855
# 3   2017              87420
# 4   2018             130254
# 5   2019             166819
# 6   2020             124684
# 7   2021             331498
# 8   2022            1024723
# 9   2023            1525179
# 10  2024             143182

# %%
# Calculating minimum monthly sales

minimum_monthly_sales = ev_df.groupby(['Year','Month_Name'])[['EV_Sales_Quantity']].min().reset_index()
minimum_monthly_sales
# Out:
#      Year Month_Name  EV_Sales_Quantity
# 0    2014      April                  0
# 1    2014     August                  0
# 2    2014   December                  0
# 3    2014   February                  0
# 4    2014    January                  0
# ..    ...        ...                ...
# 116  2023        May                  0
# 117  2023   November                  0
# 118  2023    October                  0
# 119  2023  September                  0
# 120  2024    January                  0
#
# [121 rows x 3 columns]

# %%
# Calculating maximum monthly sales

maximum_monthly_sales = ev_df.groupby(['Year','Month_Name'])[['EV_Sales_Quantity']].max().reset_index()
maximum_monthly_sales
# Out:
#      Year Month_Name  EV_Sales_Quantity
# 0    2014      April                104
# 1    2014     August                 50
# 2    2014   December                 83
# 3    2014   February                 76
# 4    2014    January                 78
# ..    ...        ...                ...
# 116  2023        May              19908
# 117  2023   November              18422
# 118  2023    October              17675
# 119  2023  September              19486
# 120  2024    January              17780
#
# [121 rows x 3 columns]

# %%
# Calculating average monthly sales

average_monthly_sales = ev_df.groupby(['Year','Month_Name'])[['EV_Sales_Quantity']].mean().reset_index()
average_monthly_sales
# Out:
#      Year Month_Name  EV_Sales_Quantity
# 0    2014      April           0.335553
# 1    2014     August           0.239680
# 2    2014   December           0.318121
# 3    2014   February           0.226490
# 4    2014    January           0.304862
# ..    ...        ...                ...
# 116  2023        May         183.021991
# 117  2023   November         175.212400
# 118  2023    October         161.709640
# 119  2023  September         148.769499
# 120  2024    January         166.490698
#
# [121 rows x 3 columns]

# %%
# Looking for records by state and year

state_name = input('Enter state name : ')
sales_year = int(input('Enter year : '))

record_state_year = ev_df.loc[(ev_df['Year'] == sales_year) & (ev_df['State'] == state_name)]
record_state_year
# Out:
# Enter state name :  Odisha
# Enter year :  2015
#        Year Month_Name       Date   State                Vehicle_Class  \
# 1225   2015    January 2015-01-01  Odisha              ADAPTED VEHICLE
# 1226   2015    January 2015-01-01  Odisha         AGRICULTURAL TRACTOR
# 1227   2015    January 2015-01-01  Odisha                    AMBULANCE
# 1228   2015    January 2015-01-01  Odisha          ARTICULATED VEHICLE
# 1229   2015    January 2015-01-01  Odisha                          BUS
# ...     ...        ...        ...     ...                          ...
# 90012  2015   December 2015-01-12  Odisha    THREE WHEELER (PASSENGER)
# 90013  2015   December 2015-01-12  Odisha         TRACTOR (COMMERCIAL)
# 90014  2015   December 2015-01-12  Odisha  TRACTOR-TROLLEY(COMMERCIAL)
# 90015  2015   December 2015-01-12  Odisha       TRAILER (AGRICULTURAL)
# 90016  2015   December 2015-01-12  Odisha         TRAILER (COMMERCIAL)
#
#       Vehicle_Category Vehicle_Type  EV_Sales_Quantity
# 1225            Others       Others                  0
# 1226            Others       Others                  0
# 1227            Others       Others                  0
# 1228            Others       Others                  0
# 1229               Bus          Bus                  0
# ...                ...          ...                ...
# 90012       3-Wheelers    3W_Shared                  0
# 90013           Others       Others                  0
# 90014           Others       Others                  0
# 90015           Others       Others                  0
# 90016           Others       Others                  0
#
# [350 rows x 8 columns]

# %%
# Calculating total EV sales by state

total_sales_state = ev_df.groupby('State').agg(Total_Sales = ('EV_Sales_Quantity','sum'))\
                        .sort_values(by = 'Total_Sales', ascending = False)\
                        .reset_index()
total_sales_state
# Out:
#                        State  Total_Sales
# 0              Uttar Pradesh       732074
# 1                Maharashtra       401535
# 2                  Karnataka       315498
# 3                      Delhi       268538
# 4                  Rajasthan       228573
# 5                      Bihar       213465
# 6                 Tamil Nadu       206902
# 7                    Gujarat       176713
# 8                      Assam       151917
# 9                     Kerala       133246
# 10            Madhya Pradesh       133182
# 11                    Odisha        86823
# 12                   Haryana        85250
# 13               West Bengal        78112
# 14            Andhra Pradesh        77356
# 15              Chhattisgarh        75275
# 16               Uttarakhand        57606
# 17                    Punjab        49285
# 18                 Jharkhand        47871
# 19                   Tripura        18346
# 20                       Goa        17382
# 21         Jammu and Kashmir        16840
# 22                Chandigarh        11453
# 23                Puducherry         5139
# 24          Himachal Pradesh         2886
# 25                   Manipur         1284
# 26                DNH and DD          431
# 27                   Mizoram          235
# 28                 Meghalaya          208
# 29  Andaman & Nicobar Island          202
# 30                    Ladakh           88
# 31                  Nagaland           52
# 32         Arunachal Pradesh           40
# 33                    Sikkim            4

# %% [markdown]
# * Uttar Pradesh tops in total sales of EV's which is around 732074 followed by Maharashtra 401535 and Karnataka 315498.

# %%
# Calculating average EV sales by state

avg_sales_state = ev_df.groupby('State').agg(Average_Sales = ('EV_Sales_Quantity','mean'))\
                                        .sort_values(by = 'Average_Sales',ascending = False)\
                                        .reset_index()
avg_sales_state.round(2)
# Out:
#                        State  Average_Sales
# 0              Uttar Pradesh         160.65
# 1                      Delhi         143.53
# 2                      Bihar          83.91
# 3                Maharashtra          81.75
# 4                  Karnataka          65.32
# 5                 Tamil Nadu          50.92
# 6                  Rajasthan          50.21
# 7                      Assam          48.79
# 8                    Gujarat          39.12
# 9             Madhya Pradesh          37.13
# 10                    Kerala          36.35
# 11            Andhra Pradesh          22.38
# 12                   Haryana          22.19
# 13                    Odisha          21.56
# 14              Chhattisgarh          20.97
# 15               Uttarakhand          18.92
# 16               West Bengal          18.62
# 17                 Jharkhand          17.26
# 18                    Punjab          16.71
# 19                   Tripura          11.73
# 20                       Goa           8.13
# 21                Chandigarh           7.37
# 22         Jammu and Kashmir           7.35
# 23                Puducherry           2.81
# 24          Himachal Pradesh           0.97
# 25                   Manipur           0.79
# 26                DNH and DD           0.22
# 27  Andaman & Nicobar Island           0.16
# 28                   Mizoram           0.15
# 29                 Meghalaya           0.11
# 30                    Ladakh           0.08
# 31                  Nagaland           0.03
# 32         Arunachal Pradesh           0.02
# 33                    Sikkim           0.00

# %% [markdown]
# * Uttar Pradesh tops in average sales of EV's which is around 160.65 followed by Delhi 143.53 and Bihar 83.91.

# %%
# Calculating top 5 months with highest sales

top_months = ev_df.groupby('Month_Name').agg(Total_Sales = ('EV_Sales_Quantity','sum')).sort_values(by = 'Total_Sales',ascending = False)[:5]
top_months
# Out:
#             Total_Sales
# Month_Name
# November         382217
# December         364558
# January          360703
# October          355083
# September        313433

# %% [markdown]
# * November has the highest sales over the years which is around 382217 followed by December 364558 and January 360703.
# * It is likely that people are buying EV's during winters.

# %%
# Calculating total sales of vehicle type

total_sales_vehicle_type = ev_df.groupby('Vehicle_Type').agg(Total_sales = ('EV_Sales_Quantity','sum'))\
                                                        .sort_values(by = 'Total_sales' ,ascending = False).reset_index()
total_sales_vehicle_type
# Out:
#           Vehicle_Type  Total_sales
# 0          2W_Personal      1796340
# 1   3W_Shared_LowSpeed      1408127
# 2          4W_Personal       130676
# 3    3W_Goods_LowSpeed        90656
# 4            3W_Shared        76132
# 5             3W_Goods        44974
# 6            4W_Shared        19099
# 7            2W_Shared        11765
# 8               Others         8612
# 9                  Bus         7009
# 10         3W_Personal          421
# 11     Institution Bus            0

# %% [markdown]
# * 2 wheeler personal has highest total sales of 1796340 followed by 3 wheeler shared low speed 1408127 and 4 wheeler personal 130676.

# %%
# Plotting vehicle type and ev sales

plt.figure(figsize=(10,4))
sns.barplot(x='Vehicle_Type', y='EV_Sales_Quantity',data=ev_df,hue='Vehicle_Type', palette='bright')
plt.title('Analysis by Vehicle Type')
plt.xlabel('Vehicle Type')
plt.ylabel('EV Sales')
plt.xticks(rotation=90);

# %%
# Plotting yearly sales trend

plt.figure(figsize = (10,5))
sns.lineplot(x = 'Year', y = 'EV_Sales_Quantity',marker = 'o', data = ev_df,color = 'orange',errorbar=None)
plt.title('Sales Per Year')
plt.xlabel('Year')
plt.ylabel('Sales')
plt.show()

# %%
# Querying for month names

month_order = ev_df['Month_Name'].unique()


# Converting Month_Name to ordered categorical

ev_df['Month_Name'] = pd.Categorical(ev_df['Month_Name'],categories = month_order,ordered = True)


# Querying for state wise monthly sales

monthly_sales = ev_df.groupby(['State','Month_Name'],observed=True).agg(Monthly_sales = ('EV_Sales_Quantity','sum')).reset_index()
state_name = input('Enter state name : ')
month_record = monthly_sales.loc[monthly_sales['State'] == state_name]
month_record
# Out:
# Enter state name :  Odisha
#       State Month_Name  Monthly_sales
# 288  Odisha    January           9203
# 289  Odisha   February           4738
# 290  Odisha      March           6968
# 291  Odisha      April           6113
# 292  Odisha        May           6397
# 293  Odisha       June           5000
# 294  Odisha       July           6009
# 295  Odisha     August           6313
# 296  Odisha  September           6924
# 297  Odisha    October          10125
# 298  Odisha   November           9846
# 299  Odisha   December           9187

# %%
# Plotting the above

plt.figure(figsize = (12,5))
sns.lineplot(x = 'Month_Name', y = 'Monthly_sales',data = month_record,color = 'orange',marker = 'o')
plt.title(f'Monthly sales of {state_name}')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.show()

# %%
# Creating pivot table for vehicle type vs year with total sales per year

Vehicle_Type_pivot = pd.pivot_table(ev_df,index = 'Vehicle_Type', columns = 'Year', values = 'EV_Sales_Quantity',aggfunc='sum')
Vehicle_Type_pivot
# Out:
# Year                2014  2015   2016   2017    2018    2019   2020    2021  \
# Vehicle_Type
# 2W_Personal         1679  1447   1460   1525   16795   28912  27015  154380
# 2W_Shared              0     0      0      3     264    1445   2095    1816
# 3W_Goods               3     7     27    114     169     423    372    4545
# 3W_Goods_LowSpeed      0    10    158   1175    2737    4982   6074   14623
# 3W_Personal            2     0      5     13      48      29     50      36
# 3W_Shared              7   307   1295    518     656     882   1522    3521
# 3W_Shared_LowSpeed     0  5116  45867  81710  106841  127852  83218  137184
# 4W_Personal          482   677    615    827    1023     962   3215   12253
# 4W_Shared             16    84     77    281     565     704    986     749
# Bus                    3     4      5     17      49     506     88    1177
# Institution Bus        0     0      0      0       0       0      0       0
# Others               200   153    346   1237    1107     122     49    1214
#
# Year                  2022    2023   2024
# Vehicle_Type
# 2W_Personal         626993  854831  81303
# 2W_Shared             4097    2005     40
# 3W_Goods             12697   24693   1924
# 3W_Goods_LowSpeed    21909   35253   3735
# 3W_Personal            107     110     21
# 3W_Shared            11948   48626   6850
# 3W_Shared_LowSpeed  306081  473866  40392
# 4W_Personal          33173   70868   6581
# 4W_Shared             4997    9253   1387
# Bus                   1988    2666    506
# Institution Bus          0       0      0
# Others                 733    3008    443

# %%
# Creating pivot table for state vs year with total sales per year

state_pivot = pd.pivot_table(ev_df, index = 'State',columns = 'Year', values = 'EV_Sales_Quantity', aggfunc = 'sum')
state_pivot
# Out:
# Year                      2014  2015   2016   2017   2018   2019   2020  \
# State
# Andaman & Nicobar Island     0     0      0      0     20      2     36
# Andhra Pradesh              12     8     20      0   1165   2123   1623
# Arunachal Pradesh            0     0      1      0      1      1      5
# Assam                        2    23     19   3833   7403  10867   8357
# Bihar                       12    69   1100   3593   8469  12380  12447
# Chandigarh                   0     2      1     23    213    506    369
# Chhattisgarh               123    86    192    945   1902   2744   1489
# DNH and DD                   0     2      2      1     19     19     24
# Delhi                       48  3565  21688  18042  20961  23222  12378
# Goa                          9     4     34     39     26     41     80
# Gujarat                     76    81    142    174    498    945   1120
# Haryana                      9    55   1381   2488   4623   5108   2982
# Himachal Pradesh             1     4      4     15     62     54    181
# Jammu and Kashmir            4     5      0      1     90     76     74
# Jharkhand                    4   194    705   1352   1957   1931   1516
# Karnataka                  601   682    605    729   2302   6152   9716
# Kerala                      26    27     19     77    264    471   1386
# Ladakh                       0     0      0      0      0      0      0
# Madhya Pradesh              41    84    836   1404   2738   3680   3358
# Maharashtra                905  1015    951    945   4640   7319   7137
# Manipur                      0     0      2      5     39    251    104
# Meghalaya                    1     0      1      0      2     13      3
# Mizoram                      0     0      2      0      0      1      1
# Nagaland                     0     1      0      0      0     29     11
# Odisha                      51    47     25    212   1358   1159    904
# Puducherry                   3    11      7      9     87     80     88
# Punjab                      30    19     38    139    363    961    832
# Rajasthan                   87   676   3996   3945   4678   6633   5603
# Sikkim                       1     2      1      0      0      0      0
# Tamil Nadu                 196    86     86    118   1332   3444   5698
# Tripura                      0     0      0      2     32   1459   3421
# Uttar Pradesh              139  1012  15310  40649  53212  55796  31264
# Uttarakhand                  9    14   1158   4225   5070   5819   2398
# West Bengal                  2    31   1529   4455   6728  13533  10079
#
# Year                       2021    2022    2023   2024
# State
# Andaman & Nicobar Island     92      23      26      3
# Andhra Pradesh             9540   29006   31506   2353
# Arunachal Pradesh             2       2      21      7
# Assam                     15633   40720   60798   4262
# Bihar                     23082   55752   88186   8375
# Chandigarh                  734    2719    6333    553
# Chhattisgarh               4214   22363   37638   3579
# DNH and DD                   29     140     160     35
# Delhi                     25815   62265   73487   7067
# Goa                        1095    5686    9440    928
# Gujarat                    9775   68997   88617   6288
# Haryana                    8661   25859   30489   3595
# Himachal Pradesh            327    1008    1126    104
# Jammu and Kashmir          1146    4690    9720   1034
# Jharkhand                  3741   13681   21097   1693
# Karnataka                 33314   95934  151272  14191
# Kerala                     8801   39671   74714   7790
# Ladakh                        6      40      28     14
# Madhya Pradesh            10427   36797   67051   6766
# Maharashtra               29907  136036  193935  18745
# Manipur                     114     341     399     29
# Meghalaya                     5      42     113     28
# Mizoram                       0      36     166     29
# Nagaland                      2       3       6      0
# Odisha                     5627   28444   44552   4444
# Puducherry                  405    1481    2637    331
# Punjab                     4643   14054   25741   2465
# Rajasthan                 23462   78240   93818   7435
# Sikkim                        0       0       0      0
# Tamil Nadu                30030   66955   90242   8715
# Tripura                    2435    4178    6312    507
# Uttar Pradesh             66702  162857  277300  27833
# Uttarakhand                5324   15561   16794   1234
# West Bengal                6408   11142   21455   2750

# %%
# Top 3 states with highest sales

states_sales = ev_df.groupby(['Year','State']).agg(Total_Sales = ('EV_Sales_Quantity','sum'))

states_sales['Rank'] = states_sales.groupby('Year')['Total_Sales'].rank(method = 'dense',ascending = False).astype(int)

top_3_states = states_sales[states_sales['Rank'] <= 3].sort_values(by = ['Year','Rank'])

top_3_states
# Out:
#                     Total_Sales  Rank
# Year State
# 2014 Maharashtra            905     1
#      Karnataka              601     2
#      Tamil Nadu             196     3
# 2015 Delhi                 3565     1
#      Maharashtra           1015     2
#      Uttar Pradesh         1012     3
# 2016 Delhi                21688     1
#      Uttar Pradesh        15310     2
#      Rajasthan             3996     3
# 2017 Uttar Pradesh        40649     1
#      Delhi                18042     2
#      West Bengal           4455     3
# 2018 Uttar Pradesh        53212     1
#      Delhi                20961     2
#      Bihar                 8469     3
# 2019 Uttar Pradesh        55796     1
#      Delhi                23222     2
#      West Bengal          13533     3
# 2020 Uttar Pradesh        31264     1
#      Bihar                12447     2
#      Delhi                12378     3
# 2021 Uttar Pradesh        66702     1
#      Karnataka            33314     2
#      Tamil Nadu           30030     3
# 2022 Uttar Pradesh       162857     1
#      Maharashtra         136036     2
#      Karnataka            95934     3
# 2023 Uttar Pradesh       277300     1
#      Maharashtra         193935     2
#      Karnataka           151272     3
# 2024 Uttar Pradesh        27833     1
#      Maharashtra          18745     2
#      Karnataka            14191     3

# %%
# Ranking vehicle_Type by total sales

vehicle = ev_df.groupby('Vehicle_Type').agg(Total_Sales = ('EV_Sales_Quantity','sum'))

vehicle['Rank'] = vehicle['Total_Sales'].rank(method = 'dense', ascending = False).astype(int)

top_vehicle_type = vehicle.sort_values(by = 'Rank')

top_vehicle_type
# Out:
#                     Total_Sales  Rank
# Vehicle_Type
# 2W_Personal             1796340     1
# 3W_Shared_LowSpeed      1408127     2
# 4W_Personal              130676     3
# 3W_Goods_LowSpeed         90656     4
# 3W_Shared                 76132     5
# 3W_Goods                  44974     6
# 4W_Shared                 19099     7
# 2W_Shared                 11765     8
# Others                     8612     9
# Bus                        7009    10
# 3W_Personal                 421    11
# Institution Bus               0    12

# %%
# Calculating YoY (Year-over-Year) growth rate

YoY_growth = ev_df.groupby('Year').agg(Total_Sales = ('EV_Sales_Quantity','sum'))
YoY_growth['YoY_Growth_prcent'] = YoY_growth['Total_Sales'].pct_change()*100
YoY_growth.round(2)
# Out:
#       Total_Sales  YoY_Growth_prcent
# Year
# 2014         2392                NaN
# 2015         7805             226.30
# 2016        49855             538.76
# 2017        87420              75.35
# 2018       130254              49.00
# 2019       166819              28.07
# 2020       124684             -25.26
# 2021       331498             165.87
# 2022      1024723             209.12
# 2023      1525179              48.84
# 2024       143182             -90.61

# %% [markdown]
# * YoY growth has risen from 2014 to 2016 around 538%.
# * Then it dipped from 2017 to 2020 to -25.26%.
# * Again it has been increased from 2021 to 2022 to 209.12%.
# * Then again dipped to -90.61% in 2024.

# %%
# Calculating CAGR

def calculate_cagr(start_value, end_value, periods):
    cagr = ((end_value / start_value) ** (1 / periods)) - 1
    return round(cagr * 100, 2)

# Creating Values

start_value = total_sales_years['EV_Sales_Quantity'].iloc[0]
end_value = total_sales_years['EV_Sales_Quantity'].iloc[-1]
periods = total_sales_years['Year'].iloc[-1] - total_sales_years['Year'].iloc[0]

cagr = calculate_cagr(start_value,end_value,periods)
    
print(f'CAGR over {periods} years : {cagr}% ')
# Out:
# CAGR over 10 years : 50.56%

# %% [markdown]
# * The annual CAGR for last 10 years is 50.56%.

# %% [markdown]
# ### Analysis

# %% [markdown]
# * There are some years where monthly sales are 0.
# * Uttar Pradesh tops in EV sales followed by Maharashtra and Karnataka in total sales over the years.
# * Uttar Pradesh tops in EV sales followed by Delhi and Bihar in average sales over the years.
# * Month of November is seen the highest total sales followed by December and January.
# * It is likely that people are buying during winters.
# * 2 wheeler personal vehicle type has maximum sales followed by 3 wheeler shared low speed and 4 wheeler personal.
# * Yearly sales of EV's has risen from 2014 to 2024.
# * YoY growth has risen from 2014 to 2016 then it dipped from 2017 to 2020 then again risen from 2021 to 2022 then again dipped in 2023 and 2024.
# * The annual CAGR for last 10 years is 50.56%.
